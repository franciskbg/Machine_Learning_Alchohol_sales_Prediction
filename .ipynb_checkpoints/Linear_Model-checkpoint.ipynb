# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

import datetime

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error,median_absolute_error
from sklearn.model_selection import KFold, cross_val_score, cross_val_predict

import random

from sklearn.linear_model import LinearRegression

# %%
## Load the data into a DataFrame
stores_all=pd.read_csv('Data/Iowa_cleanHeaders.csv')
stores_all.head(10)
# Out:
#    Unnamed: 0  Unnamed    index Invoice_Item_Number        Date  Store_Number  \
# 0           0        0   284394     INV-14210900001  2018-09-04          4617
# 1           1        1  1367141     INV-14210900002  2018-09-04          4617
# 2           2        2  4766887     INV-14210900003  2018-09-04          4617
# 3           3        3  5505505     INV-17983700005  2019-03-07          5425
# 4           4        4  5505506     INV-17956400075  2019-03-06          2500
# 5           5        5  5505507     INV-18453000022  2019-03-29          2445
# 6           6        6  5505508     INV-18030300035  2019-03-11          2528
# 7           7        7  5505509     INV-17934800043  2019-03-05          3705
# 8           8        8  5505510     INV-18062400027  2019-03-11          2459
# 9           9        9  5505511     INV-18032400010  2019-03-11          4962
#
#                           Store_Name              Address            City  \
# 0                     Lickety Liquor     2501 HUBBELL AVE      Des Moines
# 1                     Lickety Liquor     2501 HUBBELL AVE      Des Moines
# 2                     Lickety Liquor     2501 HUBBELL AVE      Des Moines
# 3                     Spirits Liquor    109 E 1st St. # B          Grimes
# 4        Hy-Vee Food Store #1 / Ames   3800 W Lincoln Way            Ames
# 5               Ruback's Food Center    504 South Highway         Oakland
# 6  Hy-Vee Food Store #3 / Des Moines      3221 SE 14th St      Des Moines
# 7                      Liquor Locker     507 1st Ave #100     Rock Rapids
# 8                     Reinhart Foods  200 State Po Box 98  Guthrie Center
# 9                    Hilltop Grocery     1312 Harrison St       Davenport
#
#    Zip_Code  ... State_Bottle_Retail  Bottles_Sold Sale_Dollars  \
# 0   50317.0  ...                2.70            48       129.60
# 1   50317.0  ...                7.05             6        42.30
# 2   50317.0  ...               23.36             4        93.44
# 3   50111.0  ...               45.00             1        45.00
# 4   50010.0  ...               18.75             4        75.00
# 5   51560.0  ...               14.25             2        28.50
# 6   50315.0  ...               18.75            12       225.00
# 7   51246.0  ...               12.39             2        24.78
# 8   50115.0  ...               15.00             1        15.00
# 9   52803.0  ...                5.25            24       126.00
#
#    Volume_Sold_Liters Volume_Sold_Gallons  Iowa_ZIP_Code_Tabulation_Areas  \
# 0               18.00                4.75                            87.0
# 1                3.00                0.79                            87.0
# 2                3.00                0.79                            87.0
# 3                3.50                0.92                             NaN
# 4                3.00                0.79                             NaN
# 5                2.00                0.52                             NaN
# 6                9.00                2.37                             NaN
# 7                1.50                0.39                             NaN
# 8                1.75                0.46                             NaN
# 9                9.00                2.37                             NaN
#
#   Iowa_Watershed_Sub-Basins_HUC_08  Iowa_Watersheds_HUC_10  \
# 0                             29.0                   342.0
# 1                             29.0                   342.0
# 2                             29.0                   342.0
# 3                              NaN                     NaN
# 4                              NaN                     NaN
# 5                              NaN                     NaN
# 6                              NaN                     NaN
# 7                              NaN                     NaN
# 8                              NaN                     NaN
# 9                              NaN                     NaN
#
#   County_Boundaries_of_Iowa  US_Counties
# 0                      64.0       1878.0
# 1                      64.0       1878.0
# 2                      64.0       1878.0
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
#
# [10 rows x 32 columns]

# %%
 stores_all["Date"] = pd.to_datetime(stores_all["Date"])

# %%
def DataInspect(dataframe):
    print("Dataframe Shape:", dataframe.shape,"\n")
    print("Duplicate Rows:", dataframe.duplicated().sum(),"\n") #Added this
    print("Dataframe Types \n\n", dataframe.dtypes,"\n")    
    print("Missing Values \n\n", dataframe.isnull().sum(),"\n")
    print("Dataframe Describe \n\n", dataframe.describe(include='all'),"\n")


    print('Unique Values by Variable')
    for item in dataframe:
        print(item,':',dataframe[item].nunique())

# %%
DataInspect(stores_all)
# Out:
# Dataframe Shape: (3671454, 32)
#
# Duplicate Rows: 0
#
# Dataframe Types
#
#  Unnamed: 0                                   int64
# Unnamed                                      int64
# index                                        int64
# Invoice_Item_Number                         object
# Date                                datetime64[ns]
# Store_Number                                 int64
# Store_Name                                  object
# Address                                     object
# City                                        object
# Zip_Code                                   float64
# Store_Location                              object
# County_Number                              float64
# County                                      object
# Category                                   float64
# Category_Name                               object
# Vendor_Number                              float64
# Vendor_Name                                 object
# Item_Number                                  int64
# Item_Description                            object
# Pack                                         int64
# Bottle _volume_ml                            int64
# State_Bottle_Cost                          float64
# State_Bottle_Retail                        float64
# Bottles_Sold                                 int64
# Sale_Dollars                               float64
# Volume_Sold_Liters                         float64
# Volume_Sold_Gallons                        float64
# Iowa_ZIP_Code_Tabulation_Areas             float64
# Iowa_Watershed_Sub-Basins_HUC_08           float64
# Iowa_Watersheds_HUC_10                     float64
# County_Boundaries_of_Iowa                  float64
# US_Counties                                float64
# dtype: object
#
# Missing Values
#
#  Unnamed: 0                               0
# Unnamed                                  0
# index                                    0
# Invoice_Item_Number                      0
# Date                                     0
# Store_Number                             0
# Store_Name                               0
# Address                               2281
# City                                  2281
# Zip_Code                              2281
# Store_Location                      332951
# County_Number                         2283
# County                                2281
# Category                              3400
# Category_Name                         3400
# Vendor_Number                            2
# Vendor_Name                              2
# Item_Number                              0
# Item_Description                         0
# Pack                                     0
# Bottle _volume_ml                        0
# State_Bottle_Cost                        0
# State_Bottle_Retail                      0
# Bottles_Sold                             0
# Sale_Dollars                             0
# Volume_Sold_Liters                       0
# Volume_Sold_Gallons                      0
# Iowa_ZIP_Code_Tabulation_Areas      333277
# Iowa_Watershed_Sub-Basins_HUC_08    333277
# Iowa_Watersheds_HUC_10              333277
# County_Boundaries_of_Iowa           333277
# US_Counties                         332951
# dtype: int64
#
# Dataframe Describe
#
#            Unnamed: 0       Unnamed         index Invoice_Item_Number  \
# count   3.671454e+06  3.671454e+06  3.671454e+06             3671454
# unique           NaN           NaN           NaN             3495556
# top              NaN           NaN           NaN     INV-18109600025
# freq             NaN           NaN           NaN                   2
# first            NaN           NaN           NaN                 NaN
# last             NaN           NaN           NaN                 NaN
# mean    1.835726e+06  1.835726e+06  9.756344e+06                 NaN
# std     1.059858e+06  1.059858e+06  2.951478e+06                 NaN
# min     0.000000e+00  0.000000e+00  2.843940e+05                 NaN
# 25%     9.178632e+05  9.178632e+05  6.517816e+06                 NaN
# 50%     1.835726e+06  1.835726e+06  9.094348e+06                 NaN
# 75%     2.753590e+06  2.753590e+06  1.307976e+07                 NaN
# max     3.671453e+06  3.671453e+06  1.399796e+07                 NaN
#
#                        Date  Store_Number                    Store_Name  \
# count               3671454  3.671454e+06                       3671454
# unique                  384           NaN                          1736
# top     2019-03-05 00:00:00           NaN  Hy-Vee #3 / BDI / Des Moines
# freq                  21834           NaN                         34344
# first   2018-01-02 00:00:00           NaN                           NaN
# last    2019-06-28 00:00:00           NaN                           NaN
# mean                    NaN  3.863113e+03                           NaN
# std                     NaN  1.112715e+03                           NaN
# min                     NaN  2.106000e+03                           NaN
# 25%                     NaN  2.622000e+03                           NaN
# 50%                     NaN  3.920000e+03                           NaN
# 75%                     NaN  4.895000e+03                           NaN
# max                     NaN  9.938000e+03                           NaN
#
#                 Address        City      Zip_Code  ... State_Bottle_Retail  \
# count           3669173     3669173  3.669173e+06  ...        3.671454e+06
# unique             1690         418           NaN  ...                 NaN
# top     3221 SE 14th St  Des Moines           NaN  ...                 NaN
# freq              45440      318336           NaN  ...                 NaN
# first               NaN         NaN           NaN  ...                 NaN
# last                NaN         NaN           NaN  ...                 NaN
# mean                NaN         NaN  5.126536e+04  ...        1.532405e+01
# std                 NaN         NaN  9.877166e+02  ...        1.382197e+01
# min                 NaN         NaN  5.000200e+04  ...        1.340000e+00
# 25%                 NaN         NaN  5.031600e+04  ...        8.250000e+00
# 50%                 NaN         NaN  5.110300e+04  ...        1.238000e+01
# 75%                 NaN         NaN  5.230200e+04  ...        1.889000e+01
# max                 NaN         NaN  8.090400e+04  ...        2.806800e+03
#
#         Bottles_Sold  Sale_Dollars  Volume_Sold_Liters Volume_Sold_Gallons  \
# count   3.671454e+06  3.671454e+06        3.671454e+06        3.671454e+06
# unique           NaN           NaN                 NaN                 NaN
# top              NaN           NaN                 NaN                 NaN
# freq             NaN           NaN                 NaN                 NaN
# first            NaN           NaN                 NaN                 NaN
# last             NaN           NaN                 NaN                 NaN
# mean    1.089276e+01  1.420999e+02        9.327470e+00        2.460736e+00
# std     2.995854e+01  4.885326e+02        3.566990e+01        9.423122e+00
# min     0.000000e+00  0.000000e+00        2.000000e-02        0.000000e+00
# 25%     2.000000e+00  3.240000e+01        1.500000e+00        4.000000e-01
# 50%     6.000000e+00  7.244000e+01        5.000000e+00        1.320000e+00
# 75%     1.200000e+01  1.440000e+02        1.050000e+01        2.770000e+00
# max     1.195200e+04  2.795573e+05        8.964000e+03        2.368030e+03
#
#         Iowa_ZIP_Code_Tabulation_Areas Iowa_Watershed_Sub-Basins_HUC_08  \
# count                     3.338177e+06                     3.338177e+06
# unique                             NaN                              NaN
# top                                NaN                              NaN
# freq                               NaN                              NaN
# first                              NaN                              NaN
# last                               NaN                              NaN
# mean                      5.038105e+02                     2.719653e+01
# std                       2.653165e+02                     1.367972e+01
# min                       1.000000e+00                     1.000000e+00
# 25%                       2.330000e+02                     1.800000e+01
# 50%                       5.230000e+02                     2.500000e+01
# 75%                       7.670000e+02                     3.500000e+01
# max                       9.350000e+02                     5.600000e+01
#
#         Iowa_Watersheds_HUC_10 County_Boundaries_of_Iowa   US_Counties
# count             3.338177e+06              3.338177e+06  3.338503e+06
# unique                     NaN                       NaN           NaN
# top                        NaN                       NaN           NaN
# freq                       NaN                       NaN           NaN
# first                      NaN                       NaN           NaN
# last                       NaN                       NaN           NaN
# mean              2.487155e+02              5.175841e+01  1.290803e+03
# std               1.133336e+02              2.122187e+01  7.384595e+02
# min               3.000000e+00              1.000000e+00  1.740000e+02
# 25%               1.380000e+02              3.500000e+01  2.910000e+02
# 50%               2.640000e+02              5.700000e+01  1.787000e+03
# 75%               3.320000e+02              6.400000e+01  1.878000e+03
# max               5.340000e+02              9.900000e+01  2.735000e+03
#
# [13 rows x 32 columns]
#
# Unique Values by Variable
# Unnamed: 0 : 3671454
# Unnamed : 3671454
# index : 3671454
# Invoice_Item_Number : 3495556
# Date : 384
# Store_Number : 1705
# Store_Name : 1736
# Address : 1690
# City : 418
# Zip_Code : 450
# Store_Location : 1770
# County_Number : 99
# County : 132
# Category : 53
# Category_Name : 53
# Vendor_Number : 203
# Vendor_Name : 205
# Item_Number : 4413
# Item_Description : 4042
# Pack : 18
# Bottle _volume_ml : 36
# State_Bottle_Cost : 1353
# State_Bottle_Retail : 1355
# Bottles_Sold : 344
# Sale_Dollars : 11700
# Volume_Sold_Liters : 747
# Volume_Sold_Gallons : 887
# Iowa_ZIP_Code_Tabulation_Areas : 434
# Iowa_Watershed_Sub-Basins_HUC_08 : 53
# Iowa_Watersheds_HUC_10 : 264
# County_Boundaries_of_Iowa : 99
# US_Counties : 104

# %%
stores_all.head()
# Out:
#    Unnamed: 0  Unnamed    index Invoice_Item_Number       Date  Store_Number  \
# 0           0        0   284394     INV-14210900001 2018-09-04          4617
# 1           1        1  1367141     INV-14210900002 2018-09-04          4617
# 2           2        2  4766887     INV-14210900003 2018-09-04          4617
# 3           3        3  5505505     INV-17983700005 2019-03-07          5425
# 4           4        4  5505506     INV-17956400075 2019-03-06          2500
#
#                     Store_Name             Address        City  Zip_Code  ...  \
# 0               Lickety Liquor    2501 HUBBELL AVE  Des Moines   50317.0  ...
# 1               Lickety Liquor    2501 HUBBELL AVE  Des Moines   50317.0  ...
# 2               Lickety Liquor    2501 HUBBELL AVE  Des Moines   50317.0  ...
# 3               Spirits Liquor   109 E 1st St. # B      Grimes   50111.0  ...
# 4  Hy-Vee Food Store #1 / Ames  3800 W Lincoln Way        Ames   50010.0  ...
#
#   State_Bottle_Retail  Bottles_Sold Sale_Dollars  Volume_Sold_Liters  \
# 0                2.70            48       129.60                18.0
# 1                7.05             6        42.30                 3.0
# 2               23.36             4        93.44                 3.0
# 3               45.00             1        45.00                 3.5
# 4               18.75             4        75.00                 3.0
#
#   Volume_Sold_Gallons  Iowa_ZIP_Code_Tabulation_Areas  \
# 0                4.75                            87.0
# 1                0.79                            87.0
# 2                0.79                            87.0
# 3                0.92                             NaN
# 4                0.79                             NaN
#
#   Iowa_Watershed_Sub-Basins_HUC_08  Iowa_Watersheds_HUC_10  \
# 0                             29.0                   342.0
# 1                             29.0                   342.0
# 2                             29.0                   342.0
# 3                              NaN                     NaN
# 4                              NaN                     NaN
#
#   County_Boundaries_of_Iowa  US_Counties
# 0                      64.0       1878.0
# 1                      64.0       1878.0
# 2                      64.0       1878.0
# 3                       NaN          NaN
# 4                       NaN          NaN
#
# [5 rows x 32 columns]

# %%
#let's try to drop all the duplicate
Stores_iowa =  stores_all.drop(stores_all[stores_all.duplicated()].index,axis=0)

# %%
Stores_iowa.shape
# Out:
# (3671454, 32)

# %%
#let's drop rows that we don't need
Stores_iowa.drop(['Unnamed: 0','Unnamed'],axis=1,inplace=True)
Stores_iowa.shape
# Out:
# (3671454, 30)

# %%
Stores_iowa.columns
# Out:
# Index(['index', 'Invoice_Item_Number', 'Date', 'Store_Number', 'Store_Name',
#        'Address', 'City', 'Zip_Code', 'Store_Location', 'County_Number',
#        'County', 'Category', 'Category_Name', 'Vendor_Number', 'Vendor_Name',
#        'Item_Number', 'Item_Description', 'Pack', 'Bottle _volume_ml',
#        'State_Bottle_Cost', 'State_Bottle_Retail', 'Bottles_Sold',
#        'Sale_Dollars', 'Volume_Sold_Liters', 'Volume_Sold_Gallons',
#        'Iowa_ZIP_Code_Tabulation_Areas', 'Iowa_Watershed_Sub-Basins_HUC_08',
#        'Iowa_Watersheds_HUC_10', 'County_Boundaries_of_Iowa', 'US_Counties'],
#       dtype='object')

# %%
Stores_iowa.drop(['Iowa_ZIP_Code_Tabulation_Areas', 'Iowa_Watershed_Sub-Basins_HUC_08',
       'Iowa_Watersheds_HUC_10', 'County_Boundaries_of_Iowa', 'US_Counties'],axis=1,inplace=True)
Stores_iowa.shape
# Out:
# (3671454, 25)

# %%
#Let's see how the counties if we remove duplicates data in counties and drop all duplicates

# counties_iowa = Stores_iowa[Stores_iowa[['city','Zip_Code','County_Number','county']].duplicated()==False][['city','Zip_Code', 'County_Number','county']]

counties_iowa = Stores_iowa[Stores_iowa['County_Number'].notnull() & Stores_iowa['County'].notnull()]
counties_iowa['County'].nunique()
# Out:
# 131

# %%
#drop all null values irregardless of columns
counties_iowa.dropna()
counties_iowa.head()
# Out:
#      index Invoice_Item_Number       Date  Store_Number  \
# 0   284394     INV-14210900001 2018-09-04          4617
# 1  1367141     INV-14210900002 2018-09-04          4617
# 2  4766887     INV-14210900003 2018-09-04          4617
# 3  5505505     INV-17983700005 2019-03-07          5425
# 4  5505506     INV-17956400075 2019-03-06          2500
#
#                     Store_Name             Address        City  Zip_Code  \
# 0               Lickety Liquor    2501 HUBBELL AVE  Des Moines   50317.0
# 1               Lickety Liquor    2501 HUBBELL AVE  Des Moines   50317.0
# 2               Lickety Liquor    2501 HUBBELL AVE  Des Moines   50317.0
# 3               Spirits Liquor   109 E 1st St. # B      Grimes   50111.0
# 4  Hy-Vee Food Store #1 / Ames  3800 W Lincoln Way        Ames   50010.0
#
#                  Store_Location  County_Number  ... Item_Number  \
# 0  POINT (-93.570489 41.607817)           77.0  ...       36904
# 1  POINT (-93.570489 41.607817)           77.0  ...       36901
# 2  POINT (-93.570489 41.607817)           77.0  ...       26826
# 3                           NaN           77.0  ...      100015
# 4                           NaN           85.0  ...       34456
#
#                 Item_Description Pack  Bottle _volume_ml State_Bottle_Cost  \
# 0            Mccormick Vodka Pet   24                375              1.80
# 1           McCormick Vodka Mini    6                500              4.70
# 2  Jack Daniels Old #7 Black Lbl   12                750             15.57
# 3            Fireball Bag in Box    3               3500             30.00
# 4                      Ketel One   12                750             12.50
#
#    State_Bottle_Retail Bottles_Sold  Sale_Dollars  Volume_Sold_Liters  \
# 0                 2.70           48        129.60                18.0
# 1                 7.05            6         42.30                 3.0
# 2                23.36            4         93.44                 3.0
# 3                45.00            1         45.00                 3.5
# 4                18.75            4         75.00                 3.0
#
#    Volume_Sold_Gallons
# 0                 4.75
# 1                 0.79
# 2                 0.79
# 3                 0.92
# 4                 0.79
#
# [5 rows x 25 columns]

# %%
counties_iowa.shape
# Out:
# (3669171, 25)

# %% [markdown]
# #PREDICTING 2019 SALES BASED ON 2018

# %%
#Let's separate the data to see how many data each year has

iowa_2019 = counties_iowa[counties_iowa['Date'] > '2018-12-31']
print(iowa_2019.shape)

# we'll try to isolate 2018 data from 2019 in order for us to train the datatraining data
iowa_2018 = counties_iowa[counties_iowa['Date'] < '2019-01-01']
print(iowa_2018.shape)

print(iowa_2018.shape[0] + iowa_2018.shape[0])
# Out:
# (1315308, 25)
# (2353863, 25)
# 4707726

# %%
# print(iowa_2019['Date'].describe())
# print('')
# # print(iowa_2018['Date'].describe())

# %%
iowa_2019.columns
# Out:
# Index(['index', 'Invoice_Item_Number', 'Date', 'Store_Number', 'Store_Name',
#        'Address', 'City', 'Zip_Code', 'Store_Location', 'County_Number',
#        'County', 'Category', 'Category_Name', 'Vendor_Number', 'Vendor_Name',
#        'Item_Number', 'Item_Description', 'Pack', 'Bottle _volume_ml',
#        'State_Bottle_Cost', 'State_Bottle_Retail', 'Bottles_Sold',
#        'Sale_Dollars', 'Volume_Sold_Liters', 'Volume_Sold_Gallons'],
#       dtype='object')

# %% [markdown]
# LET'S PLAY AND SEE HOW HEACH STORE PERFORMED IN 2018

# %%
#Sales DONE BY STORE
store_location_2018 = iowa_2018.groupby('Store_Number')[['Bottle _volume_ml','State_Bottle_Cost','State_Bottle_Retail', 'Bottles_Sold',
                                                'Sale_Dollars', 'Volume_Sold_Liters', 'Volume_Sold_Gallons']].sum()
store_location_2018.head()
# Out:
#               Bottle _volume_ml  State_Bottle_Cost  State_Bottle_Retail  \
# Store_Number
# 2106                    4226520           51737.90             77617.44
# 2113                    1577000           17992.37             26992.84
# 2130                    3518070           42474.49             63720.64
# 2178                    2392225           24864.82             37302.83
# 2190                   10809570          183014.55            274551.71
#
#               Bottles_Sold  Sale_Dollars  Volume_Sold_Liters  \
# Store_Number
# 2106                 93410    1337244.94            87658.57
# 2113                  5645      80578.24             5647.12
# 2130                 74820    1184941.20            68643.59
# 2178                 21389     311540.25            23205.70
# 2190                120527    1755604.23            76696.71
#
#               Volume_Sold_Gallons
# Store_Number
# 2106                     23152.33
# 2113                      1488.04
# 2130                     18130.14
# 2178                      6124.66
# 2190                     20231.29

# %%
# Let's see the sales of alchol based on county
county_location_2018= iowa_2018.groupby('County')[['Bottle _volume_ml','State_Bottle_Cost','State_Bottle_Retail', 'Bottles_Sold',
                                                'Sale_Dollars', 'Volume_Sold_Liters', 'Volume_Sold_Gallons']].sum()
county_location_2018.head()
# Out:
#            Bottle _volume_ml  State_Bottle_Cost  State_Bottle_Retail  \
# County
# ADAIR                2241325           21267.20             31905.68
# ADAMS                1446400           14893.81             22343.74
# ALLAMAKEE            9847510           96174.52            144282.95
# APPANOOSE            7389300           77790.33            116702.46
# AUDUBON              2712775           24920.94             37387.38
#
#            Bottles_Sold  Sale_Dollars  Volume_Sold_Liters  Volume_Sold_Gallons
# County
# ADAIR             18578     235301.43            17492.72              4615.26
# ADAMS              3881      57235.57             4081.16              1074.90
# ALLAMAKEE         63550     882149.45            69171.11             18250.44
# APPANOOSE         68370     896239.71            62827.76             16580.81
# AUDUBON           16071     183616.27            14683.96              3870.64

# %%
#checking to see how many location has sales less than 5000,000
county_location_2018[(county_location_2018['Sale_Dollars'] < 500000)].sort_values('Sale_Dollars',ascending=False).count()
# Out:
# Bottle _volume_ml      47
# State_Bottle_Cost      47
# State_Bottle_Retail    47
# Bottles_Sold           47
# Sale_Dollars           47
# Volume_Sold_Liters     47
# Volume_Sold_Gallons    47
# dtype: int64

# %% [markdown]
# Let's group and aggregat the sales based

# %%
# WE WILL CHANGE THE WAY THE DATE APPEARS AND ONLY SHOW THE DATE AS A MONTH

monthly_2018 = iowa_2018.groupby([iowa_2018['Date'].dt.strftime('%B'),'Store_Number'])[['Bottle _volume_ml','State_Bottle_Cost','State_Bottle_Retail', 'Bottles_Sold',
                                            'Sale_Dollars', 'Volume_Sold_Liters', 'Volume_Sold_Gallons']].sum().reset_index()
monthly_2018.head()
# Out:
#     Date  Store_Number  Bottle _volume_ml  State_Bottle_Cost  \
# 0  April          2106             345950            4117.15
# 1  April          2113             118125            1444.62
# 2  April          2130             286100            3595.96
# 3  April          2178             160800            1619.63
# 4  April          2190             959050           17019.15
#
#    State_Bottle_Retail  Bottles_Sold  Sale_Dollars  Volume_Sold_Liters  \
# 0              6176.61          7726     110242.90             7261.35
# 1              2167.30           447       6845.47              438.86
# 2              5394.66          5677      91978.05             5214.74
# 3              2429.82          1188      16218.52             1183.74
# 4             25531.52         12516     157892.09             7035.54
#
#    Volume_Sold_Gallons
# 0              1918.56
# 1               115.93
# 2              1377.75
# 3               312.72
# 4              1859.81

# %%
# Now that we have the date changed only into month, I want to compare how the sales of ml did compare to the gallons
volume_sold_2018 = monthly_2018.pivot(index='Store_Number',columns='Date')
volume_sold_2018.columns
volume_sold_2018.head()
# Out:
#              Bottle _volume_ml                                           \
# Date                     April    August   December  February   January
# Store_Number
# 2106                  345950.0  409025.0   353050.0  307675.0  301200.0
# 2113                  118125.0   88500.0   133000.0  109625.0  150500.0
# 2130                  286100.0  384600.0   292450.0  269900.0  289400.0
# 2178                  160800.0  238625.0   249775.0  160775.0  153800.0
# 2190                  959050.0  939025.0  1049200.0  695825.0  720900.0
#
#                                                                  ...  \
# Date              July      June     March       May   November  ...
# Store_Number                                                     ...
# 2106          291300.0  316300.0  429425.0  454895.0   357975.0  ...
# 2113          119375.0  136125.0  165875.0  173125.0   123125.0  ...
# 2130          246100.0  246850.0  341550.0  347045.0   263250.0  ...
# 2178          181450.0  214475.0  234250.0  165075.0   269950.0  ...
# 2190          913100.0  853000.0  874650.0  914295.0  1083650.0  ...
#
#              Volume_Sold_Gallons                                               \
# Date                    December February  January     July     June    March
# Store_Number
# 2106                     2041.92  1690.20  1729.64  1485.55  1591.11  2350.94
# 2113                      127.94   104.81   132.43   116.71   147.22   144.98
# 2130                     1648.73  1438.16  1350.14  1241.23  1285.65  1925.83
# 2178                      716.87   429.58   318.34   330.06   461.28   548.82
# 2190                     2113.22  1330.41  1379.23  1915.75  1662.73  1718.02
#
#
# Date              May November  October September
# Store_Number
# 2106          2440.52  1890.76  1934.64   1703.15
# 2113           154.20   101.54   136.65    121.24
# 2130          1809.49  1456.56  1437.21   1316.54
# 2178           807.79   605.14   752.47    334.86
# 2190          1653.57  1812.19  1652.06   1548.05
#
# [5 rows x 84 columns]

# %%
# now that we have all the dataset grouped based on the alcohol volume, lets disolved them based on month and store
stores_area_sales = pd.DataFrame(volume_sold_2018.to_records())
stores_area_sales.head()
# Out:
#    Store_Number  ('Bottle _volume_ml', 'April')  \
# 0          2106                        345950.0
# 1          2113                        118125.0
# 2          2130                        286100.0
# 3          2178                        160800.0
# 4          2190                        959050.0
#
#    ('Bottle _volume_ml', 'August')  ('Bottle _volume_ml', 'December')  \
# 0                         409025.0                           353050.0
# 1                          88500.0                           133000.0
# 2                         384600.0                           292450.0
# 3                         238625.0                           249775.0
# 4                         939025.0                          1049200.0
#
#    ('Bottle _volume_ml', 'February')  ('Bottle _volume_ml', 'January')  \
# 0                           307675.0                          301200.0
# 1                           109625.0                          150500.0
# 2                           269900.0                          289400.0
# 3                           160775.0                          153800.0
# 4                           695825.0                          720900.0
#
#    ('Bottle _volume_ml', 'July')  ('Bottle _volume_ml', 'June')  \
# 0                       291300.0                       316300.0
# 1                       119375.0                       136125.0
# 2                       246100.0                       246850.0
# 3                       181450.0                       214475.0
# 4                       913100.0                       853000.0
#
#    ('Bottle _volume_ml', 'March')  ('Bottle _volume_ml', 'May')  ...  \
# 0                        429425.0                      454895.0  ...
# 1                        165875.0                      173125.0  ...
# 2                        341550.0                      347045.0  ...
# 3                        234250.0                      165075.0  ...
# 4                        874650.0                      914295.0  ...
#
#    ('Volume_Sold_Gallons', 'December')  ('Volume_Sold_Gallons', 'February')  \
# 0                              2041.92                              1690.20
# 1                               127.94                               104.81
# 2                              1648.73                              1438.16
# 3                               716.87                               429.58
# 4                              2113.22                              1330.41
#
#    ('Volume_Sold_Gallons', 'January')  ('Volume_Sold_Gallons', 'July')  \
# 0                             1729.64                          1485.55
# 1                              132.43                           116.71
# 2                             1350.14                          1241.23
# 3                              318.34                           330.06
# 4                             1379.23                          1915.75
#
#    ('Volume_Sold_Gallons', 'June')  ('Volume_Sold_Gallons', 'March')  \
# 0                          1591.11                           2350.94
# 1                           147.22                            144.98
# 2                          1285.65                           1925.83
# 3                           461.28                            548.82
# 4                          1662.73                           1718.02
#
#    ('Volume_Sold_Gallons', 'May')  ('Volume_Sold_Gallons', 'November')  \
# 0                         2440.52                              1890.76
# 1                          154.20                               101.54
# 2                         1809.49                              1456.56
# 3                          807.79                               605.14
# 4                         1653.57                              1812.19
#
#    ('Volume_Sold_Gallons', 'October')  ('Volume_Sold_Gallons', 'September')
# 0                             1934.64                               1703.15
# 1                              136.65                                121.24
# 2                             1437.21                               1316.54
# 3                              752.47                                334.86
# 4                             1652.06                               1548.05
#
# [5 rows x 85 columns]

# %%
#  let's remove the unwanted columns
iowa_sales_2018 = stores_area_sales[['Store_Number',"('Sale_Dollars', 'January')", "('Sale_Dollars', 'February')",
       "('Sale_Dollars', 'March')", "('Sale_Dollars', 'April')",
       "('Sale_Dollars', 'May')", "('Sale_Dollars', 'June')","('Sale_Dollars', 'July')","('Sale_Dollars', 'August')",
        "('Sale_Dollars', 'September')","('Sale_Dollars', 'October')","('Sale_Dollars', 'November')","('Sale_Dollars', 'December')"]]
iowa_sales_2018.head()
# Out:
#    Store_Number  ('Sale_Dollars', 'January')  ('Sale_Dollars', 'February')  \
# 0          2106                     94562.40                      93167.21
# 1          2113                      7280.55                       5084.13
# 2          2130                     87877.13                      92672.71
# 3          2178                     14989.50                      23128.58
# 4          2190                    117128.48                     114443.88
#
#    ('Sale_Dollars', 'March')  ('Sale_Dollars', 'April')  \
# 0                  138162.93                  110242.90
# 1                    8017.78                    6845.47
# 2                  123148.45                   91978.05
# 3                   28878.44                   16218.52
# 4                  143601.26                  157892.09
#
#    ('Sale_Dollars', 'May')  ('Sale_Dollars', 'June')  \
# 0                140356.71                  94917.25
# 1                  8582.22                   7747.48
# 2                114987.63                  84509.61
# 3                 38932.93                  22813.38
# 4                138025.96                 148227.29
#
#    ('Sale_Dollars', 'July')  ('Sale_Dollars', 'August')  \
# 0                  90135.36                   132690.83
# 1                   6458.65                     4272.97
# 2                  81413.10                   118929.04
# 3                  16997.42                    26945.75
# 4                 163883.29                   126270.45
#
#    ('Sale_Dollars', 'September')  ('Sale_Dollars', 'October')  \
# 0                       97067.54                    102804.27
# 1                        6570.82                      6992.27
# 2                       88363.56                     92661.06
# 3                       17196.98                     33369.91
# 4                      131375.28                    141283.93
#
#    ('Sale_Dollars', 'November')  ('Sale_Dollars', 'December')
# 0                     118259.02                     124878.52
# 1                       5474.57                       7251.33
# 2                      98990.41                     109410.45
# 3                      33185.85                      38882.99
# 4                     149763.17                     223709.15

# %%
# let's find the overall sales for each store
sales_2018 = store_location_2018[['Sale_Dollars']]
sales_2018.head()
# Out:
#               Sale_Dollars
# Store_Number
# 2106            1337244.94
# 2113              80578.24
# 2130            1184941.20
# 2178             311540.25
# 2190            1755604.23

# %%
print(iowa_sales_2018.shape)
print(sales_2018.shape)
# Out:
# (1636, 13)
# (1636, 1)

# %%
#Iin order to do my anylysis, I'll go ahead and merge annual store sales of 2019 on monthly store sales data
sales_data = pd.merge(iowa_sales_2018,sales_2018.reset_index(),on='Store_Number')
sales_data.head()
# Out:
#    Store_Number  ('Sale_Dollars', 'January')  ('Sale_Dollars', 'February')  \
# 0          2106                     94562.40                      93167.21
# 1          2113                      7280.55                       5084.13
# 2          2130                     87877.13                      92672.71
# 3          2178                     14989.50                      23128.58
# 4          2190                    117128.48                     114443.88
#
#    ('Sale_Dollars', 'March')  ('Sale_Dollars', 'April')  \
# 0                  138162.93                  110242.90
# 1                    8017.78                    6845.47
# 2                  123148.45                   91978.05
# 3                   28878.44                   16218.52
# 4                  143601.26                  157892.09
#
#    ('Sale_Dollars', 'May')  ('Sale_Dollars', 'June')  \
# 0                140356.71                  94917.25
# 1                  8582.22                   7747.48
# 2                114987.63                  84509.61
# 3                 38932.93                  22813.38
# 4                138025.96                 148227.29
#
#    ('Sale_Dollars', 'July')  ('Sale_Dollars', 'August')  \
# 0                  90135.36                   132690.83
# 1                   6458.65                     4272.97
# 2                  81413.10                   118929.04
# 3                  16997.42                    26945.75
# 4                 163883.29                   126270.45
#
#    ('Sale_Dollars', 'September')  ('Sale_Dollars', 'October')  \
# 0                       97067.54                    102804.27
# 1                        6570.82                      6992.27
# 2                       88363.56                     92661.06
# 3                       17196.98                     33369.91
# 4                      131375.28                    141283.93
#
#    ('Sale_Dollars', 'November')  ('Sale_Dollars', 'December')  Sale_Dollars
# 0                     118259.02                     124878.52    1337244.94
# 1                       5474.57                       7251.33      80578.24
# 2                      98990.41                     109410.45    1184941.20
# 3                      33185.85                      38882.99     311540.25
# 4                     149763.17                     223709.15    1755604.23

# %%
#First plot
def correlation_heat_map(df):
    corrs = df.corr()

    # Set the default matplotlib figure size:
    fig, ax = plt.subplots(figsize=(11,7))

  
    #(taken from the Seaborn example gallery):
    mask = np.zeros_like(corrs, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Plot the heatmap with Seaborn.
    # Assign the matplotlib axis the function returns. 
    #This allow us to resize the labels.
    sns.heatmap(df, cmap="BuPu")

    ax = sns.heatmap(corrs, mask=mask, annot=True, vmin=-1, vmax=1)
    

    # Resize the labels.
    ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14, rotation=30)
    ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14, rotation=0)

    # If you put plt.show() at the bottom, 
    #it prevents those useless printouts from matplotlib.
    plt.show()

# %%
#Heatmap based onstore location
correlation_heat_map(store_location_2018)

# %%
#How the store perform

sns.set(style = 'ticks')

fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(421)
_ = plt.hist(x=store_location_2018['Bottle _volume_ml'],bins=100)
_ = plt.title('Bottle Volume (mL)')

ax = fig.add_subplot(422)
_ = plt.hist(x=store_location_2018['State_Bottle_Cost'],bins=100)
_ = plt.title('State Bottle Cost')

ax = fig.add_subplot(423)
_ = plt.hist(x=store_location_2018['State_Bottle_Retail'],bins=100)
_ = plt.title('State Bottle Retail')

ax = fig.add_subplot(424)
_ = plt.hist(x=store_location_2018['Bottles_Sold'],bins=100)
_ = plt.title('Bottles Sold')

ax = fig.add_subplot(425)
_ = plt.hist(x=store_location_2018['Sale_Dollars'],bins=100)
_ = plt.title('Sale dollars')

ax = fig.add_subplot(426)
_ = plt.hist(x=store_location_2018['Volume_Sold_Liters'],bins=100)
_ = plt.title('Volume Sold (L)')

ax = fig.add_subplot(427)
_ = plt.hist(x=store_location_2018['Volume_Sold_Gallons'],bins=100)
_ = plt.title('Volume Sold (Gal)')

plt.show()

# %%
# Let's see how it does compare with the month we are looking for which is football season
footbal_season = monthly_2018[monthly_2018['Date'].isin(['August','September','October', 'November'])]
footbal_season = pd.merge(footbal_season,sales_2018.reset_index(),on='Store_Number')
footbal_season.rename(columns={'Sale_Dollars_x':'month_sales',
                       'Sale_Dollars_y':'annual_sales'},inplace=True)
footbal_season.head()
# Out:
#         Date  Store_Number  Bottle _volume_ml  State_Bottle_Cost  \
# 0     August          2106             409025            5022.83
# 1   November          2106             357975            4782.93
# 2    October          2106             321000            3705.00
# 3  September          2106             338725            4039.90
# 4     August          2113              88500            1007.64
#
#    State_Bottle_Retail  Bottles_Sold  month_sales  Volume_Sold_Liters  \
# 0              7535.24          9582    132690.83             8997.30
# 1              7175.30          7722    118259.02             7162.80
# 2              5558.29          7719    102804.27             7327.75
# 3              6060.65          6911     97067.54             6451.87
# 4              1511.69           332      4272.97              321.23
#
#    Volume_Sold_Gallons  annual_sales
# 0              2375.34    1337244.94
# 1              1890.76    1337244.94
# 2              1934.64    1337244.94
# 3              1703.15    1337244.94
# 4                84.39      80578.24

# %%
#lET'S PLOT AND SEE HOW THINGS ARE GOING
plt.scatter(footbal_season['month_sales'],footbal_season['annual_sales'])

# %%
#PLOTING THE FOOTBALL SEASON WITH THE ANUAL SALES

plt.scatter(footbal_season[footbal_season['Date']=='August']['month_sales'],
            footbal_season[footbal_season['Date']=='August']['annual_sales'])

plt.scatter(footbal_season[footbal_season['Date']=='September']['month_sales'],
            footbal_season[footbal_season['Date']=='September']['annual_sales'])

plt.scatter(footbal_season[footbal_season['Date']=='October']['month_sales'],
            footbal_season[footbal_season['Date']=='October']['annual_sales'])

plt.scatter(footbal_season[footbal_season['Date']=='November']['month_sales'],
            footbal_season[footbal_season['Date']=='November']['annual_sales'])
